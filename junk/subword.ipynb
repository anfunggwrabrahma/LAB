# %%
# !pip install subword-nmt

# %%
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Sep  2 05:49 .
# drwxr-xr-x 1 root root 4096 Sep  2 05:47 ..
# drwxr-xr-x 4 root root 4096 Aug 31 13:24 .config
# drwx------ 5 root root 4096 Sep  2 05:49 drive
# drwxr-xr-x 1 root root 4096 Aug 31 13:25 sample_data
