# %%
# !pip install wheel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
# ...

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- ---------
# boltons                 23.0.0
# brotlipy                0.7.0
# certifi                 2022.12.7
# cffi                    1.15.1
# charset-normalizer      2.0.4
# conda                   23.3.1
# conda-content-trust     0.1.3
# conda-package-handling  2.0.2
# conda_package_streaming 0.7.0
# cryptography            39.0.1
# idna                    3.4
# jsonpatch               1.32
# jsonpointer             2.1
# packaging               23.0
# pip                     23.0.1
# pluggy                  1.0.0
# pycosat                 0.6.4
# pycparser               2.21
# pyOpenSSL               23.0.0
# PySocks                 1.7.1
# requests                2.28.1
# ruamel.yaml             0.17.21
# ruamel.yaml.clib        0.2.6
# setuptools              65.6.3
# six                     1.16.0
# toolz                   0.12.0
# tqdm                    4.65.0
# urllib3                 1.26.15
# ...

# %%
# !pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install --no-deps OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 12.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pyonmttok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 47.0 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opennmt-py 3.1.2 requires configargparse, which is not installed.
# opennmt-py 3.1.2 requires ctranslate2<4,>=3.2, which is not installed.
# opennmt-py 3.1.2 requires gcld3, which is not installed.
# opennmt-py 3.1.2 requires pyahocorasick, which is not installed.
# opennmt-py 3.1.2 requires rapidfuzz, which is not installed.
# opennmt-py 3.1.2 requires sacrebleu, which is not installed.
# opennmt-py 3.1.2 requires waitress, which is not installed.
# opennmt-py 3.1.2 requires torch<2,>=1.13, but you have torch 2.0.0+cu118 which is incompatible.
# ...

# %%
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.0/32.0 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 89.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 113.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.8/647.8 kB 69.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 60.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# !cd OpenNMT-py
# !pip install -e .
# Out:
# Cloning into 'OpenNMT-py'...
# remote: Enumerating objects: 19714, done.
# remote: Counting objects: 100% (562/562), done.
# remote: Compressing objects: 100% (308/308), done.
# remote: Total 19714 (delta 342), reused 419 (delta 239), pack-reused 19152
# Receiving objects: 100% (19714/19714), 276.24 MiB | 37.27 MiB/s, done.
# Resolving deltas: 100% (14275/14275), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !ls
# Out:
# drive  OpenNMT-py  sample_data

# %%
# !cd OpenNMT-py&&pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/OpenNMT-py
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
# ...
#   Using cached ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# ...
#   Using cached ctranslate2-3.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32.0 MB)
# ...
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# ...
#   Using cached pyonmttok-1.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
# ...
#   Using cached sacrebleu-2.3.1-py3-none-any.whl (118 kB)
# ...
#   Using cached rapidfuzz-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ...
#   Using cached pyahocorasick-2.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 76.8 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# drive  OpenNMT-py  sample_data

# %%
# !onmt_build_vocab -config /content/drive/MyDrive/Data/config.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-05-15 08:09:59,358 INFO] Counter vocab from 10000 samples.
# [2023-05-15 08:09:59,359 INFO] Build vocab on 10000 transformed examples/corpus.
# [2023-05-15 08:10:00,115 WARNING] Empty line  in corpus_1#1661.
# [2023-05-15 08:10:00,226 WARNING] Empty line  in corpus_1#4488.
# [2023-05-15 08:10:00,260 WARNING] Empty line  in corpus_1#5187.
# [2023-05-15 08:10:00,302 WARNING] Empty line  in corpus_1#6229.
# [2023-05-15 08:10:00,302 WARNING] Empty line  in corpus_1#6235.
# [2023-05-15 08:10:00,367 WARNING] Empty line  in corpus_1#7814.
# [2023-05-15 08:10:00,368 WARNING] Empty line  in corpus_1#7816.
# [2023-05-15 08:10:00,368 WARNING] Empty line  in corpus_1#7818.
# [2023-05-15 08:10:00,368 WARNING] Empty line  in corpus_1#7821.
# [2023-05-15 08:10:00,368 WARNING] Empty line  in corpus_1#7824.
# [2023-05-15 08:10:00,368 WARNING] Empty line  in corpus_1#7825.
# ...

# %%
# !onmt_train -config /content/drive/MyDrive/Data/config.yaml
# Out:
# Streaming output truncated to the last 5000 lines.
# [2023-05-10 17:34:09,189 WARNING] Empty line  in corpus_1#9024.
# [2023-05-10 17:34:09,345 WARNING] Empty line  in corpus_1#5187.
# [2023-05-10 17:34:09,451 WARNING] Empty line  in corpus_1#6235.
# [2023-05-10 17:34:09,567 WARNING] Empty line  in corpus_1#7813.
# [2023-05-10 17:34:09,568 WARNING] Empty line  in corpus_1#7817.
# [2023-05-10 17:34:09,577 WARNING] Empty line  in corpus_1#7827.
# [2023-05-10 17:34:09,577 WARNING] Empty line  in corpus_1#7829.
# [2023-05-10 17:34:09,577 WARNING] Empty line  in corpus_1#7835.
# [2023-05-10 17:34:09,577 WARNING] Empty line  in corpus_1#7839.
# [2023-05-10 17:34:09,577 WARNING] Empty line  in corpus_1#7843.
# [2023-05-10 17:34:09,578 WARNING] Empty line  in corpus_1#7847.
# [2023-05-10 17:34:09,578 WARNING] Empty line  in corpus_1#7849.
# [2023-05-10 17:34:09,578 WARNING] Empty line  in corpus_1#7855.
# [2023-05-10 17:34:09,578 WARNING] Empty line  in corpus_1#7859.
# ...

# %%
# !onmt_translate -model /content/drive/MyDrive/Data/model_step_92000.pt -src /content/drive/MyDrive/Data/src-test.txt -output /content/drive/MyDrive/Data/pred_92000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 3555: ['In', 'the', 'past', ',', '<unk>', 'was', 'a', 'very', 'common', 'condition', '.']
# PRED 3555: <unk> , <unk> जोबोर सरासनस्रा <unk> जादोंमोन।
# PRED SCORE: -0.0263
#
# [2023-05-10 18:15:02,198 INFO]
# SENT 3556: ['However', ',', 'today', ',', 'as', 'a', 'result', 'of', 'widespread', '<unk>', ',', 'the', 'number', 'of', '<unk>', 'cases', 'has', 'been', 'dramatically', 'reduced', '.']
# PRED 3556: नाथाय दिनै बांद्राय <unk> <unk> <unk> , बांद्राय <unk> बेराम <unk> <unk> थायो।
# PRED SCORE: -0.3066
#
# [2023-05-10 18:15:02,199 INFO]
# SENT 3557: ['Since', '1993', ',', 'there', 'have', 'not', 'been', 'any', 'cases', 'of', '<unk>', 'in', 'the', 'UK', ',', 'and', 'there', 'are', 'now', 'only', 'four', 'countries', 'where', 'the', 'condition', 'remains', 'a', 'serious', 'problem', '-', '<unk>', ',', 'India', ',', 'Afghanistan', ',', 'and', 'Pakistan', '.']
# ...
