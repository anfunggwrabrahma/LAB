# %%
# !pip install xvfbwrapper
import os
from xvfbwrapper import Xvfb

# Start a virtual display
vdisplay = Xvfb()
vdisplay.start()

# Set the DISPLAY environment variable
os.environ['DISPLAY'] = ':1'

# Your GUI code here
import tkinter as tk

root = tk.Tk()
root.title("Hello, Colab!")
label = tk.Label(root, text="Welcome to Google Colab!")
label.pack()
root.mainloop()

# Stop the virtual display
vdisplay.stop()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xvfbwrapper
#   Downloading xvfbwrapper-0.2.9.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: xvfbwrapper
#   Building wheel for xvfbwrapper (setup.py) ... done
#   Created wheel for xvfbwrapper: filename=xvfbwrapper-0.2.9-py3-none-any.whl size=5024 sha256=e62ef56455d66270011566104af7c9a661d7ade3400e3f22a551b9433bae65f6
#   Stored in directory: /root/.cache/pip/wheels/cb/10/7d/2b7fdffccf837f7d5425931575fbee9caebe2c190931f9058b
# Successfully built xvfbwrapper
# Installing collected packages: xvfbwrapper
# Successfully installed xvfbwrapper-0.2.9
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-da2708ef110e> in <cell line: 6>()
#       4
#       5 # Start a virtual display
# ----> 6 vdisplay = Xvfb()
#       7 vdisplay.start()
#       8
#
# /usr/local/lib/python3.10/dist-packages/xvfbwrapper.py in __init__(self, width, height, colordepth, tempdir, **kwargs)
#      39         if not self.xvfb_exists():
#      40             msg = 'Can not find Xvfb. Please install it and try again.'
# ---> 41             raise EnvironmentError(msg)
#      42
#      43         self.extra_xvfb_args = ['-screen', '0', '{}x{}x{}'.format(
#
# OSError: Can not find Xvfb. Please install it and try again.

# %%
import tkinter as tk

def check_login():
    username = username_entry.get()
    password = password_entry.get()
    if username == "myusername" and password == "mypassword":
        print("Login successful!")
    else:
        print("Invalid login credentials.")

# Create the login window
root = tk.Tk()
root.title("Login")

# Create the username label and entry field
username_label = tk.Label(root, text="Username:")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

# Create the password label and entry field
password_label = tk.Label(root, text="Password:")
password_label.pack()
password_entry = tk.Entry(root, show="*")
password_entry.pack()

# Create the login button
login_button = tk.Button(root, text="Login", command=check_login)
login_button.pack()

# Start the login window
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-3-5b6d5d058dc6> in <cell line: 12>()
#      10
#      11 # Create the login window
# ---> 12 root = tk.Tk()
#      13 root.title("Login")
#      14
#
# /usr/lib/python3.10/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2300                 baseName = baseName + ext
#    2301         interactive = False
# -> 2302         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2303         if useTk:
#    2304             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
