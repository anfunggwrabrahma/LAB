# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.0 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
# !pip install subword-nmt
# Out:
# Collecting subword-nmt
#   Downloading subword_nmt-0.3.8-py3-none-any.whl (27 kB)
# Collecting mock (from subword-nmt)
#   Downloading mock-5.1.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from subword-nmt) (4.66.1)
# Installing collected packages: mock, subword-nmt
# Successfully installed mock-5.1.0 subword-nmt-0.3.8

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !chmod +x /content/drive/MyDrive/mt/scrip.sh

# %%
# !bash /content/drive/MyDrive/mt/scrip.sh
# Out:
# /content/drive/MyDrive/mt/scrip.sh: line 2: $'\r': command not found
# usage: subword-nmt [-h]
#                    {learn-bpe,apply-bpe,get-vocab,learn-joint-bpe-and-vocab}
#                    ...
# subword-nmt: error: unrecognized arguments:
# Error: invalid line 1 in BPE codes file:
# The line should exist of exactly two subword units, separated by whitespace
# /content/drive/MyDrive/mt/scrip.sh: line 5: $'\r': command not found
# usage: subword-nmt [-h]
#                    {learn-bpe,apply-bpe,get-vocab,learn-joint-bpe-and-vocab}
#                    ...
# subword-nmt: error: unrecognized arguments:
# Error: invalid line 1 in BPE codes file:
# The line should exist of exactly two subword units, separated by whitespace
