# %%
# !pip install torchviz
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4130 sha256=3158a8b83b4f3e68d0acba167780ea1387b8548dfaecd6b7939b2c7700f07bad
#   Stored in directory: /root/.cache/pip/wheels/4c/97/88/a02973217949e0db0c9f4346d154085f4725f99c4f15a87094
# Successfully built torchviz
# ...

# %%
import torch
import torchviz
import torch.nn as nn

# Define a simplified Transformer model
class Transformer(nn.Module):
    def __init__(self, d_model, nhead, num_encoder_layers, num_decoder_layers):
        super(Transformer, self).__init__()
        self.transformer = nn.Transformer(
            d_model=d_model,
            nhead=nhead,
            num_encoder_layers=num_encoder_layers,
            num_decoder_layers=num_decoder_layers
        )

    def forward(self, src, tgt):
        return self.transformer(src, tgt)

# Instantiate the model
d_model = 512
nhead = 8
num_encoder_layers = 6
num_decoder_layers = 6

model = Transformer(d_model, nhead, num_encoder_layers, num_decoder_layers)

# Create dummy inputs
src = torch.rand(10, 32, d_model)
tgt = torch.rand(20, 32, d_model)

# Generate the visualization
torchviz.make_dot(model(src, tgt)).view()
# Out:
# 'Digraph.gv.pdf'

# %%
import shutil
shutil.move("Digraph.gv.pdf", "/content/Digraph.gv.pdf")
# Out:
# '/content/Digraph.gv.pdf'

# %%
from IPython.display import Image
Image(filename="Digraph.gv.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-9ecd47d7cdeb> in <cell line: 2>()
#       1 from IPython.display import Image
# ----> 2 Image(filename="Digraph.gv.pdf")
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1221
#    1222         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1223             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1224         if self.embed:
#    1225             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'pdf' image format
