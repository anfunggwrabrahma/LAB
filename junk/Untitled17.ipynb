# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/side_project/training.csv")
df
# Out:
#       S. No.                                               text task_1
# 0          1       गोदाव खामानि मावओ बोला नो सानसे देरहा थारगोन    NOT
# 1          2                            निखावरि सुबुंफोरा सिखाव    HOF
# 2          3       मा बिमा ख'र' परिबर्थननि खोथा फैखो बेयाव मोसौ    HOF
# 3          4            थोद जामबा सैमा साला मा मिसेस जाखो बेलाय    HOF
# 4          5  माखौ बकिबाय थादों नों बोरमा फानथा दम दंब्ला खा...    HOF
# ...      ...                                                ...    ...
# 1674    1675  नोंलाय जामबा नोंबो सासे सनमान गैयै मानसिसो गिद...    HOF
# 1675    1676  एै मावजि लाब गैया दानो बनद खालामनायनि खोथा बुं...    HOF
# 1676    1677                          सिखला फुरकव रपे खलामनांगव    HOF
# 1677    1678                      सेनदेल खुबै नांगौलै सालाफोरखौ    HOF
# 1678    1679  राकेस बोरमा सिखावजोंनो थाफाहैदोलै नोंबो आदै जा...    HOF
#
# [1679 rows x 3 columns]

# %%
df = df.drop("S. No.", axis=1)
df
# Out:
#                                                    text task_1
# 0          गोदाव खामानि मावओ बोला नो सानसे देरहा थारगोन    NOT
# 1                               निखावरि सुबुंफोरा सिखाव    HOF
# 2          मा बिमा ख'र' परिबर्थननि खोथा फैखो बेयाव मोसौ    HOF
# 3               थोद जामबा सैमा साला मा मिसेस जाखो बेलाय    HOF
# 4     माखौ बकिबाय थादों नों बोरमा फानथा दम दंब्ला खा...    HOF
# ...                                                 ...    ...
# 1674  नोंलाय जामबा नोंबो सासे सनमान गैयै मानसिसो गिद...    HOF
# 1675  एै मावजि लाब गैया दानो बनद खालामनायनि खोथा बुं...    HOF
# 1676                          सिखला फुरकव रपे खलामनांगव    HOF
# 1677                      सेनदेल खुबै नांगौलै सालाफोरखौ    HOF
# 1678  राकेस बोरमा सिखावजोंनो थाफाहैदोलै नोंबो आदै जा...    HOF
#
# [1679 rows x 2 columns]

# %%
data=df["text"]
data.head()
# Out:
# 0         गोदाव खामानि मावओ बोला नो सानसे देरहा थारगोन
# 1                              निखावरि सुबुंफोरा सिखाव
# 2         मा बिमा ख'र' परिबर्थननि खोथा फैखो बेयाव मोसौ
# 3              थोद जामबा सैमा साला मा मिसेस जाखो बेलाय
# 4    माखौ बकिबाय थादों नों बोरमा फानथा दम दंब्ला खा...
# Name: text, dtype: object

# %%
data.to_csv("/content/drive/MyDrive/side_project/data.csv")
df1=pd.read_csv("/content/drive/MyDrive/side_project/data.csv")
df1
# Out:
#       Unnamed: 0                                               text
# 0              0       गोदाव खामानि मावओ बोला नो सानसे देरहा थारगोन
# 1              1                            निखावरि सुबुंफोरा सिखाव
# 2              2       मा बिमा ख'र' परिबर्थननि खोथा फैखो बेयाव मोसौ
# 3              3            थोद जामबा सैमा साला मा मिसेस जाखो बेलाय
# 4              4  माखौ बकिबाय थादों नों बोरमा फानथा दम दंब्ला खा...
# ...          ...                                                ...
# 1674        1674  नोंलाय जामबा नोंबो सासे सनमान गैयै मानसिसो गिद...
# 1675        1675  एै मावजि लाब गैया दानो बनद खालामनायनि खोथा बुं...
# 1676        1676                          सिखला फुरकव रपे खलामनांगव
# 1677        1677                      सेनदेल खुबै नांगौलै सालाफोरखौ
# 1678        1678  राकेस बोरमा सिखावजोंनो थाफाहैदोलै नोंबो आदै जा...
#
# [1679 rows x 2 columns]

# %%
df1 = df1.drop(columns=['Unnamed: 0'])

# Write the modified DataFrame back to a new CSV file
df1.to_csv('/content/drive/MyDrive/side_project/new_data.csv', index=False)

# %%
pd.read_csv("/content/drive/MyDrive/side_project/new_data.csv",nrows=5)
# Out:
#                                                 text
# 0       गोदाव खामानि मावओ बोला नो सानसे देरहा थारगोन
# 1                            निखावरि सुबुंफोरा सिखाव
# 2       मा बिमा ख'र' परिबर्थननि खोथा फैखो बेयाव मोसौ
# 3            थोद जामबा सैमा साला मा मिसेस जाखो बेलाय
# 4  माखौ बकिबाय थादों नों बोरमा फानथा दम दंब्ला खा...

# %%
# !pip install bodotokenizer

# %%
from bodotokenizer import tokenize_file
tokenize_file("/content/drive/MyDrive/side_project/new_data.csv", "/content/drive/MyDrive/side_project/token.txt")

# %%
# !pip install tokenizers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 19.8 MB/s eta 0:00:00
# ...

# %%
# !pip show tokenizers
# Out:
# Name: tokenizers
# Version: 0.13.3
# Summary: Fast and Customizable Tokenizers
# Home-page: https://github.com/huggingface/tokenizers
# Author: Anthony MOI
# Author-email: anthony@huggingface.co
# License: Apache License 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:

# %%
# !pip install --upgrade tokenizers

# %%
from tokenizers import BPETokenizer
vocab = "/content/drive/MyDrive/side_project/brx-bpe-tokenizer-vocab.json"
merges = "/content/drive/MyDrive/side_project/brx-bpe-tokenizer-merges.txt"
tokenizer = BPETokenizer(vocab, merges)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-457dffdcad00> in <cell line: 1>()
# ----> 1 from tokenizers import BPETokenizer
#       2 vocab = "/content/drive/MyDrive/side_project/brx-bpe-tokenizer-vocab.json"
#       3 merges = "/content/drive/MyDrive/side_project/brx-bpe-tokenizer-merges.txt"
#       4 tokenizer = BPETokenizer(vocab, merges)
#
# ImportError: cannot import name 'BPETokenizer' from 'tokenizers' (/usr/local/lib/python3.10/dist-packages/tokenizers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
