# %%
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !onmt_build_vocab -config /content/drive/MyDrive/Data/config.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-05-01 17:48:36,017 INFO] Counter vocab from 10000 samples.
# [2023-05-01 17:48:36,017 INFO] Build vocab on 10000 transformed examples/corpus.
# [2023-05-01 17:48:36,224 WARNING] Empty line  in corpus_1#1661.
# [2023-05-01 17:48:36,326 WARNING] Empty line  in corpus_1#4488.
# [2023-05-01 17:48:36,351 WARNING] Empty line  in corpus_1#5187.
# [2023-05-01 17:48:36,392 WARNING] Empty line  in corpus_1#6229.
# [2023-05-01 17:48:36,393 WARNING] Empty line  in corpus_1#6235.
# [2023-05-01 17:48:36,454 WARNING] Empty line  in corpus_1#7814.
# [2023-05-01 17:48:36,454 WARNING] Empty line  in corpus_1#7816.
# [2023-05-01 17:48:36,455 WARNING] Empty line  in corpus_1#7818.
# [2023-05-01 17:48:36,455 WARNING] Empty line  in corpus_1#7821.
# [2023-05-01 17:48:36,455 WARNING] Empty line  in corpus_1#7824.
# [2023-05-01 17:48:36,455 WARNING] Empty line  in corpus_1#7825.
# ...

# %%
# !onmt_train -config /content/drive/MyDrive/Data/config.yaml
# Out:
# [2023-05-01 17:50:50,854 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2023-05-01 17:50:50,855 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-05-01 17:50:50,855 INFO] Missing transforms field for valid data, set to default: [].
# [2023-05-01 17:50:50,855 INFO] Parsed 2 corpora from -data.
# [2023-05-01 17:50:50,856 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-05-01 17:50:51,067 INFO] Building model...
# [2023-05-01 17:50:57,189 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(23944, 500, padding_idx=1)
#         )
#       )
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (rnn): LSTM(500, 500, num_layers=2, batch_first=True, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
# !onmt_translate -model /content/drive/MyDrive/Data/model_step_1000.pt -src /content/drive/MyDrive/Data/src-test.txt -output /content/drive/MyDrive/Data/pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 3555: ['In', 'the', 'past', ',', '<unk>', 'was', 'a', 'very', 'common', 'condition', '.']
# PRED 3555: <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# PRED SCORE: -0.5892
#
# [2023-05-01 17:58:58,403 INFO]
# SENT 3556: ['However', ',', 'today', ',', 'as', 'a', 'result', 'of', 'widespread', '<unk>', ',', 'the', 'number', 'of', '<unk>', 'cases', 'has', 'been', 'dramatically', 'reduced', '.']
# PRED 3556: <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# PRED SCORE: -0.5151
#
# [2023-05-01 17:58:58,403 INFO]
# SENT 3557: ['Since', '1993', ',', 'there', 'have', 'not', 'been', 'any', 'cases', 'of', '<unk>', 'in', 'the', 'UK', ',', 'and', 'there', 'are', 'now', 'only', 'four', 'countries', 'where', 'the', 'condition', 'remains', 'a', 'serious', 'problem', '-', '<unk>', ',', 'India', ',', 'Afghanistan', ',', 'and', 'Pakistan', '.']
# ...
