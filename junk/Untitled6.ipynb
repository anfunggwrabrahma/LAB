# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Load data from CSV file
df = pd.read_csv('/content/drive/MyDrive/merged_file.csv')

# Extract English and Bodo sentences as lists
english_sentences = df['English'].tolist()
bodo_sentences = df['Bodo'].tolist()

# %%
import nltk
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')

# Loading the data
df = pd.read_csv('/content/drive/MyDrive/merged_file.csv')

# Replacing missing values with an empty string
df = df.replace(np.nan, '', regex=True)

# Set parameters
vocab_size = 1000
d_model = 128
num_layers = 2
num_heads = 8
dff = 512
dropout_rate = 0.1

# Tokenizing and normalizing the text
bodo_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', num_words=vocab_size)
bodo_tokenizer.fit_on_texts(bodo_data)

english_data = [' '.join(word_tokenize(str(sent).lower())) for sent in df['English']]
bodo_data = [' '.join(word_tokenize(str(sent).lower())) for sent in df['Bodo']]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0a6c4a30514f> in <cell line: 22>()
#      20 # Tokenizing and normalizing the text
#      21 bodo_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', num_words=vocab_size)
# ---> 22 bodo_tokenizer.fit_on_texts(bodo_data)
#      23
#      24 english_data = [' '.join(word_tokenize(str(sent).lower())) for sent in df['English']]
#
# NameError: name 'bodo_data' is not defined
