# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/merged_file.csv')
df
# Out:
#        Unnamed: 0                                            English  \
# 0               0  The city is famous for its majestic forts, pal...
# 1               1  The City Palace was built by Maharaja Jai Sing...
# 2               2  The Hawa mahal was built by the Maharaja, Sawa...
# 3               3  The Amber Fort complex has several apartments ...
# 4               4  The Amber Palace is a classic example of Mugha...
# ...           ...                                                ...
# 30355       11625  Treatment of viral hepatitis does not depend o...
# 30356       11626  Vaccine available against hepatitis A is not c...
# 30357       11627     Vaccine is available against hepatitis B only.
# 30358       11628  Viral hepatitis may cause serious illness in p...
# 30359       11629  we may see such outbreaks in future as many pe...
#
#                                                     Bodo
# 0      बुहुमनां दाब दाब जायगानि दावबायारिफोरनि नोजोर ...
# ...

# %%
# !pip install OpenNMT-tf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import opennmt
# !onmt_preprocess -train_src /content/drive/MyDrive/english-bodo/train.en -train_tgt /content/drive/MyDrive/english-bodo/train.bo -save_data /content/drive/MyDrive/english-bodo/preprocessed_train -src_vocab_size 50000 -tgt_vocab_size 50000
# Out:
# /usr/local/lib/python3.10/dist-packages/opennmt/version.py:23: UserWarning: OpenNMT-tf supports TensorFlow versions 2.6.0 (included) to 2.12.0 (excluded), but you have TensorFlow 2.12.0 installed. Some features might not work properly.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# ...

# %%
# !onmt_train -data /content/drive/MyDrive/english-bodo/preprocessed_train -save_model models/translation_model -encoder_type brnn -layers 2 -rnn_size 500 -global_attention dot -batch_size 32 -optim adam -learning_rate 0.001 -gpu_ranks 0
# Out:
# /bin/bash: onmt_train: command not found
