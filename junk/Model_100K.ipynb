# %%
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# !onmt_build_vocab -config /content/drive/MyDrive/model_100K/config.yaml -n_sample 100000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-05-10 14:43:33,910 INFO] Counter vocab from 100000 samples.
# [2023-05-10 14:43:33,910 INFO] Build vocab on 100000 transformed examples/corpus.
# [2023-05-10 14:43:33,981 WARNING] Empty line  in corpus_1#1661.
# [2023-05-10 14:43:34,075 WARNING] Empty line  in corpus_1#4488.
# [2023-05-10 14:43:34,100 WARNING] Empty line  in corpus_1#5187.
# [2023-05-10 14:43:34,139 WARNING] Empty line  in corpus_1#6229.
# [2023-05-10 14:43:34,139 WARNING] Empty line  in corpus_1#6235.
# [2023-05-10 14:43:34,201 WARNING] Empty line  in corpus_1#7814.
# [2023-05-10 14:43:34,201 WARNING] Empty line  in corpus_1#7816.
# [2023-05-10 14:43:34,201 WARNING] Empty line  in corpus_1#7818.
# [2023-05-10 14:43:34,202 WARNING] Empty line  in corpus_1#7821.
# [2023-05-10 14:43:34,202 WARNING] Empty line  in corpus_1#7824.
# [2023-05-10 14:43:34,202 WARNING] Empty line  in corpus_1#7825.
# ...

# %%
# !onmt_train -config /content/drive/MyDrive/model_100K/config.yaml
# Out:
# [2023-05-10 14:42:24,822 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2023-05-10 14:42:24,823 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-05-10 14:42:24,823 INFO] Missing transforms field for valid data, set to default: [].
# [2023-05-10 14:42:24,824 INFO] Parsed 2 corpora from -data.
# [2023-05-10 14:42:24,824 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-05-10 14:42:25,017 INFO] Building model...
# [2023-05-10 14:42:28,396 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(23944, 500, padding_idx=1)
#         )
#       )
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (rnn): LSTM(500, 500, num_layers=2, batch_first=True, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
# !onmt_translate -model /content/drive/MyDrive/model_100K/model_step_100000.pt -src /content/drive/MyDrive/model_100K/src-test.txt -output /content/drive/MyDrive/model_100K/pred_100000.txt -gpu 0 -verbose
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_translate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/onmt/bin/translate.py", line 60, in main
#     translate(opt)
#   File "/usr/local/lib/python3.10/dist-packages/onmt/bin/translate.py", line 23, in translate
#     translator = build_translator(opt, logger=logger,
#   File "/usr/local/lib/python3.10/dist-packages/onmt/translate/translator.py", line 33, in build_translator
#     vocabs, model, model_opt = load_test_model(opt)
#   File "/usr/local/lib/python3.10/dist-packages/onmt/model_builder.py", line 137, in load_test_model
#     checkpoint = torch.load(model_path,
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
# ...
