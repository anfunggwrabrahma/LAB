# %% [markdown]
# Gaussian Naive Bayes

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
# Load dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Gau_dataset.csv')
df.head(6)
# Out:
#    Feature1  Feature2  Target
# 0  0.559426  2.388694       0
# 1  1.312175 -0.717315       1
# 2 -1.559849 -1.924874       0
# 3 -2.281386 -0.136856       0
# 4  1.560704 -0.427958       1
# 5  0.745428 -0.411472       1

# %%
# Scatter plot of dataset
plt.figure(figsize=(8,6))
for label in y.unique():
    plt.scatter(X[y==label]['Feature1'], X[y==label]['Feature2'], label=f'Class {label}')
plt.title('Scatter Plot of Dataset')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.legend()
plt.show()

# %%
# Split features and target
X = df[['Feature1', 'Feature2']]
y = df['Target']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize Gaussian Naive Bayes model
model = GaussianNB()

# Train the model
model.fit(X_train, y_train)

# Predict on test set
y_pred = model.predict(X_test)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Gaussian Naive Bayes Model Accuracy: {accuracy:.2f}')
# Out:
# Gaussian Naive Bayes Model Accuracy: 1.00

# %%
# Example predictions
print('Predictions for test samples:', y_pred)
# Out:
# Predictions for test samples: [1 0 1 1 1 0 1 1 0 0 0 1 1 0 0]

# %%
custom_input = [[0.5, 1.0]]
predicted_class = model.predict(custom_input)
print(f'Prediction for input {custom_input}: Class {predicted_class[0]}')
# Out:
# Prediction for input [[0.5, 1.0]]: Class 1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
